# %%
import pandas as pd
import re
import string
import sklearn
import csv

# %%
df = pd.read_csv("dataset.csv")
file = open('synopsis.txt',"r")
#df2 = pd.read_csv("synopsis2.csv")
text=file.read()
#print(text)
sentences = text.split('. ')
#print(sentences)
    
df2 = pd.DataFrame(sentences, columns=["Positive"])
df2.to_csv('synopsis3.csv', index=False)
print(df.tail())
#print(df.iloc)
# Out:
#                                               Comment  Y
# 94  Horrible movie. Boring and poorly written. I d...  1
# 95  Thor and Hulk were totally wasted.Average CGI ...  1
# 96  Endgame is a total waste of good character dev...  1
# 97  didn't think this was politically correct enou...  1
# 98  It was a long time ago that i saw a movie this...  1

# %%
k = 30 # no of comments in training positive examples.

df3 = pd.DataFrame(columns=["Comment","Y"])
spoiler_comments = []
cnt = 0
for i in range(len(df.index)):
    if(df.iloc[i]["Y"]==0):
        df3 = df3.append(df.iloc[i],ignore_index = True)
    else:
        if cnt<k:
            spoiler_comments.append((df.iloc[i])["Comment"])
            cnt+=1
        else :
            df3 = df3.append(df.iloc[i],ignore_index = True)
            
temp_df = pd.DataFrame(spoiler_comments, columns=["Positive"])
df2 = df2.append(temp_df,ignore_index = True)

""""print(df2.head())
print(df3.head())  """ 
print(df2.tail())   # train
print(df3.tail())   # test
# Out:
#                                              Positive
# 80  Other reviews have added what a hot mess this ...
# 81  As Soon as ant man enters the movie with his t...
# 82  Why did Captain Marvel didn't do that instead ...
# 83  This movie kinda sucked. Even worse than most ...
# 84  The movie completely destroys some of the best...
#                                               Comment  Y
# 64  Horrible movie. Boring and poorly written. I d...  1
# 65  Thor and Hulk were totally wasted.Average CGI ...  1
# 66  Endgame is a total waste of good character dev...  1
# 67  didn't think this was politically correct enou...  1
# 68  It was a long time ago that i saw a movie this...  1

# %%
print(df.head())
# Out:
#                                              Comment  Y
# 0  Avengers Endgame is the best superhero movie e...  1
# 1  This movie is worth every penny.Go see it . yo...  0
# 2  No movie will be like this one . The ultimate ...  0
# 3  It was an amazing and sad experience at the sa...  1
# 4  This was movie was the perfect way to bring to...  1

# %%
len(df.index)
# Out:
# 99

# %%
index=[]
for i in range(len(df2.index)):
    index.append("Positive "+str(i))
#df.insert(loc=0,column='index',value=index)
df2['index']=index
df2.set_index('index', inplace=True)

index2=[]
for i in range(len(df3.index)):
    index2.append("Comment "+str(i))
#df.insert(loc=0,column='index',value=index)
df3['index']=index2
df3.set_index('index', inplace=True)
df3
# Out:
#                                                       Comment  Y
# index
# Comment 0   This movie is worth every penny.Go see it . yo...  0
# Comment 1   No movie will be like this one . The ultimate ...  0
# Comment 2   If you haven't seen this movie, you need to ge...  0
# Comment 3   I can't describe how many emotions went throug...  0
# Comment 4   The Best Marvel movie ever seen. Emotional and...  0
# Comment 5   The movie wraps up everything perfectly, that ...  0
# Comment 6   This masterpiece brings you joy, tears, excite...  0
# Comment 7   The final chapter of the Avengers started of u...  0
# Comment 8   I've been looking forward to this for so long,...  0
# Comment 9   This is a good movie. But it could have been b...  0
# Comment 10  The almost 3 hours flew by with great writing ...  0
# Comment 11  This film is the masterpiece of the genre. Wha...  0
# Comment 12  By the time Avengers: Endgame (2019) still fre...  0
# Comment 13  I am a huge Marvel fan and have loved the prev...  0
# Comment 14  watch all films with an open mind and went int...  0
# Comment 15  This film really let itself down. The writers ...  0
# Comment 16  Don't waste your money at the cinema, maybe Go...  0
# Comment 17  So i just watched it for the second time yeste...  0
# Comment 18  The storyline being absolutely terrible is alm...  0
# Comment 19  The plot was messy, and so vast, with so many ...  0
# Comment 20  The movie also proves Time Travel should never...  1
# Comment 21  Frank Capra had a golden rule - a movie can be...  0
# Comment 22  I don't know where to start!! Plot holes all t...  1
# Comment 23  This movie is a desaster. I had high hopes tha...  1
# Comment 24  First half plain boring, dialogues rubbish. Th...  1
# Comment 25  This movie was awful; the acting was abhorrent...  0
# Comment 26  This movie is pure awesomeness. This is a movi...  0
# Comment 27  Not a patch on infinity war - in fact I would ...  0
# Comment 28  After the years of a big buildup what a big le...  1
# Comment 29  Just bad a lot of things don't ad up cap Ameri...  1
# ...                                                       ... ..
# Comment 39  This movie sets up the rules of time travel - ...  1
# Comment 40  I think it was one of the worst superhero movi...  1
# Comment 41  Wow horrible weak Story..i feel like am watchi...  0
# Comment 42  Don't believe the reviews. I suspect it's peop...  0
# Comment 43  What a horrible way to end. A waste of 11 year...  0
# Comment 44  The length of the movie increased with long ta...  0
# Comment 45  Expected more much more as a fan I have contin...  0
# Comment 46  2hours, no joke.. on a story that struggled to...  1
# Comment 47  If I had a time stone I'd get those 188 minute...  1
# Comment 48  The movie unsuccessful attempted to get sensua...  0
# Comment 49   did not like Endgame. Infinity War was so goo...  1
# Comment 50  I was avenger fan, but what I saw was really j...  1
# Comment 51  After Infinity Wars, this is what utter disapp...  1
# Comment 52  Watched this on first day of opening. I was ho...  0
# Comment 53  Having come out of Infinity Wars blown away, t...  1
# Comment 54  Such a disappointment. They over hyped it. Too...  1
# Comment 55  Main problem with this movie is too much humor...  1
# Comment 56  Thanos...In Infinity War they've created the m...  1
# Comment 57  The death of Tony Stark was completely unneces...  1
# Comment 58  I wanted to see a MCU movie not a comedy movie...  0
# Comment 59  I just want to say a few things: Cap can sudde...  1
# Comment 60  I saw the movie this tuesday ☺ (3 days before ...  1
# Comment 61  I really liked all of previous Marvel films, b...  0
# Comment 62  the scene to get the soul stone, it was obviou...  1
# Comment 63  Horrible movie. Boring and poorly written. I d...  0
# Comment 64  Horrible movie. Boring and poorly written. I d...  1
# Comment 65  Thor and Hulk were totally wasted.Average CGI ...  1
# Comment 66  Endgame is a total waste of good character dev...  1
# Comment 67  didn't think this was politically correct enou...  1
# Comment 68  It was a long time ago that i saw a movie this...  1
#
# [69 rows x 2 columns]

# %%
def clean_text_round1(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text
round1 = lambda x: clean_text_round1(x)

# %%
data_clean = pd.DataFrame(df2.Positive.apply(round1))
data_clean2 = pd.DataFrame(df3.Comment.apply(round1))
data_clean
# Out:
#                                                       Positive
# index
# Positive 0   in the opening clint barton is teaching his da...
# Positive 1   suddenly clints daughter vanishes and the rest...
# Positive 2   nebula and tony stark are stranded in space fo...
# Positive 3   the team formulates a plan to steal the infini...
# Positive 4   he tells the remaining avengers that he did so...
# Positive 5   enraged thor cuts off thanos head saying its w...
# Positive 6   rogers has been leading grief counseling sessi...
# Positive 7   lang goes to romanoff and rogers and explains ...
# Positive 8   the three go to stark who is now raising a chi...
# Positive 9   stark initially rejects their proposal with co...
# Positive 10  bruce banner has now embraced the hulk as a pa...
# Positive 11  romanoff after hearing reports from rhodes of ...
# Positive 12  barton consumed with grief after the loss of h...
# Positive 13  natasha finds him in japan and after some conv...
# Positive 14  banner and rocket go to the small town of new ...
# Positive 15  they there find thor who has become overwhelme...
# Positive 16  thor has become overweight his hair and beard ...
# Positive 17  thor begrudgingly agrees to return to the aven...
# Positive 18  banner goes to the sanctum sanctorum where he ...
# Positive 19  she eventually concedes the time stone to bann...
# Positive 20  banner also promises the stones return to thei...
# Positive 21  lang and stark attempt to steal the space ston...
# Positive 22  lang gives starks past self a cardiac arrest b...
# Positive 23  their plan is thwarted when stark drops the br...
# Positive 24  loki then steals the space stone and uses it t...
# Positive 25  rogers succeeds in stealing the mind stone fro...
# Positive 26  after defeating paststeve rogers meets back up...
# Positive 27  lang returns to the present with the mind ston...
# Positive 28  army installation in the  while stealing furth...
# Positive 29  while there rogers sights peggy carter and sta...
# Positive 30  while in asgard thor is reminded that his moth...
# Positive 31  the two return to earth after frigga counsels ...
# Positive 32  nebula and rhodes travel to morag to steal the...
# Positive 33  as rhodes returns to the present with the powe...
# Positive 34  with two consciousnesses operating on nebulas ...
# Positive 35  nebula realizes what has happened and tries to...
# Positive 36  thanos scans her memories and discovers the av...
# Positive 37  barton and romanoff travel to vormir to retrie...
# Positive 38  the two fight over which will make the sacrifi...
# Positive 39  banner volunteers himself to wield the gauntle...
# Positive 40  he succeeds though they are almost immediately...
# Positive 41  thanos reduces the avengers headquarters to ru...
# Positive 42  the past nebula is killed by her future self a...
# Positive 43  the three fight thanos one on one with rogers ...
# Positive 44  soon after thanos army lands on earth tchalla ...
# Positive 45  after a lengthy battle during which stark is r...
# Positive 46  when hes bound by wanda maximoffs energy thano...
# Positive 47  captain marvel reappears taking out thanos shi...
# Positive 48  using the nanotech from the new gauntlet stark...
# Positive 49  barton and wanda maximoff take solace in the f...
# Positive 50  thor makes valkyrie the queen of asgard and jo...
# Positive 51  barton returns home to his family and parker r...
# Positive 52  meanwhile rogers is tasked to go into the past...
# Positive 53  he reappears before sam wilson and bucky barne...
# Positive 54  a brief flashback shows rogers and carter fina...

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(stop_words='english')
data_cv = cv.fit_transform(data_clean.Positive)
data_dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data_dtm.index = data_clean.index


cv2 = CountVectorizer(stop_words='english')
data_cv2 = cv2.fit_transform(data_clean2.Comment)
data_dtm2 = pd.DataFrame(data_cv2.toarray(), columns=cv2.get_feature_names())
data_dtm2.index = data_clean2.index
data_dtm
# Out:
#              able  accidentally  acquiring  actions  aether  agents  agrees  \
# index
# Positive 0      0             0          0        0       0       0       0
# Positive 1      0             0          1        0       0       0       0
# Positive 2      0             0          0        0       0       0       0
# Positive 3      0             0          0        1       0       0       0
# Positive 4      0             0          0        0       0       0       0
# Positive 5      0             0          0        0       0       0       0
# Positive 6      0             0          0        0       0       0       0
# Positive 7      0             0          0        0       0       0       0
# Positive 8      1             0          0        0       0       0       0
# Positive 9      0             0          0        0       0       0       0
# Positive 10     0             0          0        0       0       0       0
# Positive 11     0             0          0        0       0       0       0
# Positive 12     0             0          0        0       0       0       0
# Positive 13     0             0          0        0       0       0       1
# Positive 14     0             0          0        0       0       0       0
# Positive 15     0             0          0        0       0       0       0
# Positive 16     0             0          0        0       0       0       0
# Positive 17     0             0          0        0       0       0       1
# Positive 18     0             0          0        0       0       0       0
# Positive 19     0             0          0        0       0       0       0
# Positive 20     0             0          0        0       0       0       0
# Positive 21     0             0          0        0       0       0       0
# Positive 22     0             0          0        0       0       0       0
# Positive 23     0             1          0        0       0       0       0
# Positive 24     0             0          0        0       0       0       0
# Positive 25     0             0          0        0       0       1       0
# Positive 26     0             0          0        0       0       0       0
# Positive 27     0             0          0        0       0       0       0
# Positive 28     0             0          0        0       0       0       0
# Positive 29     0             0          0        0       0       0       0
# Positive 30     0             0          0        0       1       0       0
# Positive 31     0             0          0        0       0       0       0
# Positive 32     0             0          0        0       0       0       0
# Positive 33     0             0          0        0       0       0       0
# Positive 34     0             0          0        0       0       0       0
# Positive 35     0             0          0        0       0       0       0
# Positive 36     0             0          0        0       0       0       0
# Positive 37     0             0          0        0       0       0       0
# Positive 38     0             0          0        0       0       0       0
# Positive 39     0             0          0        0       0       0       0
# Positive 40     0             0          0        0       0       0       0
# Positive 41     0             0          0        0       0       0       0
# Positive 42     0             0          0        0       0       0       0
# Positive 43     0             0          0        0       0       0       0
# Positive 44     0             0          0        0       0       0       0
# Positive 45     0             0          0        0       0       0       0
# Positive 46     0             0          0        0       0       0       0
# Positive 47     0             0          0        0       0       0       0
# Positive 48     0             0          0        0       0       0       0
# Positive 49     0             0          0        0       0       0       0
# Positive 50     0             0          0        0       0       0       0
# Positive 51     0             0          0        0       0       0       0
# Positive 52     0             0          0        0       0       0       0
# Positive 53     0             0          0        0       0       0       0
# Positive 54     0             0          0        0       0       0       0
#
#              allies  allow  america  ...  wilson  withstand  work  works  \
# index                                ...
# Positive 0        0      0        0  ...       0          0     0      0
# Positive 1        0      0        0  ...       0          0     0      0
# Positive 2        0      0        0  ...       0          0     0      0
# Positive 3        0      0        0  ...       0          0     0      0
# Positive 4        0      0        0  ...       0          0     0      0
# Positive 5        0      0        0  ...       0          0     0      0
# Positive 6        0      0        0  ...       0          0     0      0
# Positive 7        0      0        0  ...       0          0     0      0
# Positive 8        0      0        0  ...       0          0     0      0
# Positive 9        0      0        0  ...       0          0     1      0
# Positive 10       0      0        0  ...       0          0     0      0
# Positive 11       0      0        0  ...       0          0     0      0
# Positive 12       0      0        0  ...       0          0     0      0
# Positive 13       0      0        0  ...       0          0     0      0
# Positive 14       0      0        0  ...       0          0     0      0
# Positive 15       0      0        0  ...       0          0     0      0
# Positive 16       0      0        0  ...       0          0     0      0
# Positive 17       0      0        0  ...       0          0     0      1
# Positive 18       0      0        0  ...       0          0     0      0
# Positive 19       0      0        0  ...       0          0     0      0
# Positive 20       0      0        0  ...       0          0     0      0
# Positive 21       0      0        0  ...       0          0     0      0
# Positive 22       0      0        0  ...       0          0     0      0
# Positive 23       0      0        0  ...       0          0     0      0
# Positive 24       0      0        0  ...       0          0     0      0
# Positive 25       0      0        0  ...       0          0     0      0
# Positive 26       0      1        0  ...       0          0     0      0
# Positive 27       0      0        0  ...       0          0     0      0
# Positive 28       0      0        0  ...       0          0     0      0
# Positive 29       0      0        0  ...       0          0     0      0
# Positive 30       0      0        0  ...       0          0     0      0
# Positive 31       0      0        0  ...       0          0     0      0
# Positive 32       0      0        0  ...       0          0     0      0
# Positive 33       0      0        0  ...       0          0     0      0
# Positive 34       0      0        0  ...       0          0     0      0
# Positive 35       0      0        0  ...       0          0     0      0
# Positive 36       0      0        0  ...       0          0     0      0
# Positive 37       0      0        0  ...       0          0     0      0
# Positive 38       0      0        0  ...       0          0     0      0
# Positive 39       0      0        0  ...       0          1     0      0
# Positive 40       0      0        0  ...       0          0     0      0
# Positive 41       0      0        0  ...       0          0     0      0
# Positive 42       0      0        0  ...       0          0     0      0
# Positive 43       0      0        0  ...       0          0     0      0
# Positive 44       1      0        0  ...       0          0     0      0
# Positive 45       0      0        0  ...       0          0     0      0
# Positive 46       0      0        0  ...       0          0     0      0
# Positive 47       0      0        0  ...       0          0     0      0
# Positive 48       0      0        0  ...       0          0     0      0
# Positive 49       0      0        0  ...       0          0     0      0
# Positive 50       0      0        0  ...       0          0     0      0
# Positive 51       0      0        0  ...       0          0     0      0
# Positive 52       0      0        0  ...       0          0     0      0
# Positive 53       0      0        1  ...       2          0     0      0
# Positive 54       0      0        0  ...       0          0     0      0
#
#              workswith  world  worthy  wrestles  years  york
# index
# Positive 0           0      0       0         0      0     0
# Positive 1           0      0       0         0      0     0
# Positive 2           0      0       0         0      0     0
# Positive 3           0      0       0         0      0     0
# Positive 4           0      0       0         0      0     0
# Positive 5           0      0       0         0      1     0
# Positive 6           0      0       0         0      0     0
# Positive 7           0      0       0         0      1     0
# Positive 8           0      0       0         0      0     0
# Positive 9           1      0       0         0      0     0
# Positive 10          0      0       0         0      0     0
# Positive 11          0      0       0         0      0     0
# Positive 12          0      1       0         0      0     0
# Positive 13          0      0       0         0      0     0
# Positive 14          0      0       0         0      0     0
# Positive 15          0      0       0         0      0     0
# Positive 16          0      0       0         0      0     0
# Positive 17          0      0       0         0      0     1
# Positive 18          0      0       0         0      0     0
# Positive 19          0      0       0         0      0     0
# Positive 20          0      0       0         0      0     0
# Positive 21          0      0       0         0      0     0
# Positive 22          0      0       0         0      0     0
# Positive 23          0      0       0         0      0     0
# Positive 24          0      0       0         0      0     0
# Positive 25          0      0       0         0      0     0
# Positive 26          0      0       0         0      0     0
# Positive 27          0      0       0         0      0     0
# Positive 28          0      0       0         0      0     0
# Positive 29          0      0       0         0      0     0
# Positive 30          0      0       0         0      0     0
# Positive 31          0      0       1         0      0     0
# Positive 32          0      0       0         0      0     0
# Positive 33          0      0       0         0      0     0
# Positive 34          0      0       0         0      0     0
# Positive 35          0      0       0         0      0     0
# Positive 36          0      0       0         0      0     0
# Positive 37          0      0       0         0      0     0
# Positive 38          0      0       0         0      0     0
# Positive 39          0      0       0         0      0     0
# Positive 40          0      0       0         0      0     0
# Positive 41          0      0       0         0      0     0
# Positive 42          0      0       0         0      0     0
# Positive 43          0      0       1         0      0     0
# Positive 44          0      0       0         0      0     0
# Positive 45          0      0       0         1      0     0
# Positive 46          0      0       0         0      0     0
# Positive 47          0      0       0         0      0     0
# Positive 48          0      0       0         0      0     0
# Positive 49          0      0       0         0      0     0
# Positive 50          0      0       0         0      0     0
# Positive 51          0      0       0         0      0     0
# Positive 52          0      0       0         0      0     0
# Positive 53          0      0       0         0      0     0
# Positive 54          0      0       0         0      0     0
#
# [55 rows x 494 columns]

# %%
import numpy as np
from gensim import matutils, models
import scipy.sparse

# %%
#print(data_dtm2.shape[1])
id_word_dict={}
word_id_dict={}
temp_set = set(data_dtm.columns)
for i in data_dtm2.columns:
    temp_set.add(i)
j=0
for word in temp_set:
    id_word_dict[j]=word
    word_id_dict[word]=j
    j+=1

# %%
no_of_words = len(id_word_dict)
train_size = len(df2.index)
test_size = len(df3.index)
X_train = np.zeros((train_size,no_of_words))
X_test = np.zeros((test_size,no_of_words))
Y_test = np.zeros(test_size)

# %%
for i in range(train_size):
    for j in range(data_dtm.shape[1]):
        index = word_id_dict[data_dtm.columns[j]]
        X_train[i][index]=data_dtm.iloc[i][j]

# %%
for i in range(test_size):
    for j in range(data_dtm2.shape[1]):
        index = word_id_dict[data_dtm2.columns[j]]
        X_test[i][index]=data_dtm2.iloc[i][j]
    Y_test[i]=df3.iloc[i]["Y"]

# %%
from sklearn.svm import OneClassSVM
lpu_model = OneClassSVM(gamma='auto').fit(X_train)
Y_out = lpu_model.predict(X_test)

# %%
wrong=0
for i in range(len(Y_out)):
    if Y_out[i]==-1 and Y_test[i]==1:
        wrong+=1
    else :
        if Y_out[i]==1 and Y_test[i]==0:
            wrong+=1
print(wrong/len(Y_out))
# Out:
# 0.5507246376811594
