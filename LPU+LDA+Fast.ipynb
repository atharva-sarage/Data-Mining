# %%
import pandas as pd
import re
import string
import sklearn
import csv

# %%
df = pd.read_csv("dataset3.csv")
file = open('synopsis_shawshank.txt',"r")
#df2 = pd.read_csv("synopsis2.csv")
text=file.read()
#print(text)
sentences = text.split('. ')
#print(sentences)
    
df2 = pd.DataFrame(sentences, columns=["Positive"])
df2.to_csv('synopsis3.csv', index=False)
print(df.tail())
# Out:
#       Unnamed: 0  is_spoiler  \
# 4356        4356       False
# 4357        4357       False
# 4358        4358       False
# 4359        4359       False
# 4360        4360       False
#
#                                             review_text Unnamed: 3 Unnamed: 4  \
# 4356  Some movies really need more than 2 hours to d...        NaN        NaN
# 4357  With all due respect to the people that compla...        NaN        NaN
# 4358  Every single scene in The Shawshank Redemption...        NaN        NaN
# 4359  At the beginning i thought, this would be an a...        NaN        NaN
# 4360  In years to come the Shawshank Redemtion will ...        NaN        NaN
#
#      Unnamed: 5
# 4356        NaN
# 4357        NaN
# 4358        NaN
# 4359        NaN
# 4360        NaN

# %%
k = 700 # no of comments in training positive examples.

df3 = pd.DataFrame(columns=["review_text","is_spoiler"])
spoiler_comments = []
cnt = 0
for i in range(len(df.index)):
    if(df.iloc[i]["is_spoiler"]==0):
        df3 = df3.append(df.iloc[i],ignore_index = True)
    else:
        if cnt<k:
            spoiler_comments.append((df.iloc[i])["review_text"])
            cnt+=1
        else :
            df3 = df3.append(df.iloc[i],ignore_index = True)
            
temp_df = pd.DataFrame(spoiler_comments, columns=["Positive"])
df2 = df2.append(temp_df,ignore_index = True)

""""print(df2.head())
print(df3.head())  """ 
print(df2.tail())   # train
print(df3.tail())   # test
# Out:
#                                               Positive
# 837  So, i watched this film thinking it'd be prett...
# 838  I was not born when this movie came out so I h...
# 839  This is a movie that does not try to outsmart ...
# 840  There aren't words too describe the greatness ...
# 841  Adapted from a Stephen King novella, The Shaws...
#                                             review_text is_spoiler  \
# 3656  Some movies really need more than 2 hours to d...      False
# 3657  With all due respect to the people that compla...      False
# 3658  Every single scene in The Shawshank Redemption...      False
# 3659  At the beginning i thought, this would be an a...      False
# 3660  In years to come the Shawshank Redemtion will ...      False
#
#       Unnamed: 0 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 3656      4356.0        NaN        NaN        NaN
# 3657      4357.0        NaN        NaN        NaN
# 3658      4358.0        NaN        NaN        NaN
# 3659      4359.0        NaN        NaN        NaN
# 3660      4360.0        NaN        NaN        NaN

# %%
index=[]
for i in range(len(df2.index)):
    index.append("Positive "+str(i))
#df.insert(loc=0,column='index',value=index)
df2['index']=index
df2.set_index('index', inplace=True)

index2=[]
for i in range(len(df3.index)):
    index2.append("Comment "+str(i))
#df.insert(loc=0,column='index',value=index)
df3['index']=index2
df3.set_index('index', inplace=True)
df3
# Out:
#                                                     review_text is_spoiler  \
# index
# Comment 0     Few movies can get this critic watching them a...       True
# Comment 1     why i think this is the best movie ever!!! ......       True
# Comment 2     Hope can set anyone free, imprisoned or not im...       True
# Comment 3     With the many other entries already here, I wo...       True
# Comment 4     The Shawshank Redemption is a great movie. You...       True
# Comment 3654    0        0  ...     0         0          0        0      0
# Comment 3655    0        0  ...     0         0          0        0      0
# Comment 3656    0        0  ...     0         0          0        0      0
# Comment 3657    0        0  ...     0         0          0        0      0
# Comment 3658    0        0  ...     0         0          0        0      0
# Comment 3659    0        0  ...     0         0          0        0      0
# Comment 3660    0        0  ...     0         0          0        0      0
#
#               ½review  ándale  été  ëfail  ëvideomalaiseí
# index
# Comment 0           0       0    0      0               0
# Comment 1           0       0    0      0               0
# Comment 2           0       0    0      0               0
# Comment 3           0       0    0      0               0
# Comment 4           0       0    0      0               0
# Comment 5           0       0    0      0               0
# Comment 6           0       0    0      0               0
# Comment 7           0       0    0      0               0
# Comment 8           0       0    0      0               0
# Comment 9           0       0    0      0               0
# Comment 10          0       0    0      0               0
# Comment 11          0       0    0      0               0
# Comment 12          0       0    0      0               0
# Comment 13          0       0    0      0               0
# Comment 14          0       0    0      0               0
# Comment 15          0       0    0      0               0
# Comment 16          0       0    0      0               0
# Comment 17          0       0    0      0               0
# Comment 18          0       0    0      0               0
# Comment 19          0       0    0      0               0
# Comment 20          0       0    0      0               0
# Comment 21          0       0    0      0               0
# Comment 22          0       0    0      0               0
# Comment 23          0       0    0      0               0
# Comment 24          0       0    0      0               0
# Comment 25          0       0    0      0               0
# Comment 26          0       0    0      0               0
# Comment 27          0       0    0      0               0
# Comment 28          0       0    0      0               0
# Comment 29          0       0    0      0               0
# ...               ...     ...  ...    ...             ...
# Comment 3631        0       0    0      0               0
# Comment 3632        0       0    0      0               0
# Comment 3633        0       0    0      0               0
# Comment 3634        0       0    0      0               0
# Comment 3635        0       0    0      0               0
# Comment 3636        0       0    0      0               0
# Comment 3637        0       0    0      0               0
# Comment 3638        0       0    0      0               0
# Comment 3639        0       0    0      0               0
# Comment 3640        0       0    0      0               0
# Comment 3641        0       0    0      0               0
# Comment 3642        0       0    0      0               0
# Comment 3643        0       0    0      0               0
# Comment 3644        0       0    0      0               0
# Comment 3645        0       0    0      0               0
# Comment 3646        0       0    0      0               0
# Comment 3647        0       0    0      0               0
# Comment 3648        0       0    0      0               0
# Comment 3649        0       0    0      0               0
# Comment 3650        0       0    0      0               0
# Comment 3651        0       0    0      0               0
# Comment 3652        0       0    0      0               0
# Comment 3653        0       0    0      0               0
# Comment 3654        0       0    0      0               0
# Comment 3655        0       0    0      0               0
# Comment 3656        0       0    0      0               0
# Comment 3657        0       0    0      0               0
# Comment 3658        0       0    0      0               0
# Comment 3659        0       0    0      0               0
# Comment 3660        0       0    0      0               0
#
# [3661 rows x 21397 columns]

# %%
# LDA
import numpy as np
from gensim import matutils, models
import scipy.sparse

sparse_counts = scipy.sparse.csr_matrix(data_dtm.transpose())
corpus = matutils.Sparse2Corpus(sparse_counts)
id_word_dict={}
for i in range(len(data_dtm.columns)):
    id_word_dict[i]=data_dtm.columns[i]

# %%
total_topics=100
lda = models.LdaMulticore(corpus=corpus, id2word=id_word_dict, num_topics=total_topics, passes=50)
#lda.print_topics()
# Out:
# /home/shivashish/anaconda3/lib/python3.7/site-packages/gensim/models/ldamodel.py:775: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %%
word_dict={}
word_dict2={}
j=0
for i in data_dtm.columns:
    word_dict[i]=j
    j+=1
j=0
for i in data_dtm2.columns:
    word_dict2[i]=j
    j+=1

# %%
word_dict2
# Out:
# {'aa': 0,
#  'aaaaaaa': 1,
#  'aaahhh': 2,
#  'aback': 3,
#  'abandon': 4,
#  'abated': 5,
#  'abbreviation': 6,
#  'abc': 7,
#  'abd': 8,
#  'abetted': 9,
#  'abhor': 10,
#  'abide': 11,
#  'abiding': 12,
#  'abilities': 13,
#  'ability': 14,
#  'abject': 15,
#  'abjectly': 16,
#  'able': 17,
#  'ably': 18,
#  'abolish': 19,
#  'abotu': 20,
#  'abound': 21,
#  'aboutalthough': 22,
#  'aboutbased': 23,
#  'aboutbut': 24,
#  'aboutdeserves': 25,
#  'aboutedgar': 26,
#  'abouti': 27,
#  'aboutif': 28,
#  'aboutim': 29,
#  'aboutit': 30,
#  'aboutmaking': 31,
#  'aboutthe': 32,
#  'aboutthis': 33,
#  'aboutwhat': 34,
#  'aboutyou': 35,
#  'aboveaverage': 36,
#  'abovethe': 37,
#  'abroad': 38,
#  'abrupt': 39,
#  'abruptly': 40,
#  'abruptlyjust': 41,
#  'abscondmentonparole': 42,
#  'absence': 43,
#  'absent': 44,
#  'absoloutely': 45,
#  'absolute': 46,
#  'absolutely': 47,
#  'absolutelyamazing': 48,
#  'absolutelyshould': 49,
#  'absolution': 50,
#  'absolutley': 51,
#  'absolutly': 52,
#  'absorb': 53,
#  'absorbed': 54,
#  'absorbing': 55,
#  'absorbs': 56,
#  'abstract': 57,
#  'abstraction': 58,
#  'absurd': 59,
#  'absurdly': 60,
#  'abundance': 61,
#  'abundant': 62,
#  'abuse': 63,
#  'abused': 64,
#  'abuses': 65,
#  'abusing': 66,
#  'abusive': 67,
#  'abut': 68,
#  'abysmal': 69,
#  'abyss': 70,
#  'abysses': 71,
#  'ac': 72,
#  'acadamy': 73,
#  'academic': 74,
#  'academy': 75,
#  'academyaward': 76,
#  'academyi': 77,
#  'academyoscar': 78,
#  'academys': 79,
#  'academyshawshank': 80,
#  'academythe': 81,
#  'accc': 82,
#  'accent': 83,
#  'accents': 84,
#  'accentuate': 85,
#  'accept': 86,
#  'acceptable': 87,
#  'acceptance': 88,
#  'accepted': 89,
#  'accepting': 90,
#  'accepts': 91,
#  'acceptsthe': 92,
#  'access': 93,
#  'accessible': 94,
#  'accesslast': 95,
#  'accessories': 96,
#  'accessory': 97,
#  'accident': 98,
#  'accidental': 99,
#  'accidentally': 100,
#  'accidents': 101,
#  'acclaim': 102,
#  'acclaimed': 103,
#  'acclaimi': 104,
#  'acclaims': 105,
#  'acclimated': 106,
#  'accolade': 107,
#  'accolades': 108,
#  'accoladetruly': 109,
#  'accommodate': 110,
#  'accommodating': 111,
#  'accommodation': 112,
#  'accompanied': 113,
#  'accompanying': 114,
#  'accomplish': 115,
#  'accomplished': 116,
#  'accomplishes': 117,
#  'accomplishing': 118,
#  'accomplishment': 119,
#  'accomplishments': 120,
#  'accord': 121,
#  'according': 122,
#  'accordingly': 123,
#  'accordinglythe': 124,
#  'accordinglythis': 125,
#  'account': 126,
#  'accountancy': 127,
#  'accountant': 128,
#  'accountants': 129,
#  'accounting': 130,
#  'accounts': 131,
#  'accreted': 132,
#  'accrued': 133,
#  'accumulate': 134,
#  'accuracy': 135,
#  'accurate': 136,
#  'accuratei': 137,
#  'accurately': 138,
#  'accuratewhether': 139,
#  'accusations': 140,
#  'accuse': 141,
#  'accused': 142,
#  'accustomed': 143,
#  'ace': 144,
#  'ache': 145,
#  'achedbecause': 146,
#  'aches': 147,
#  'achievable': 148,
#  'achieve': 149,
#  'achieved': 150,
#  'achievedi': 151,
#  'achievement': 152,
#  'achievementit': 153,
#  'achievements': 154,
#  'achievementsits': 155,
#  'achievementsso': 156,
#  'achieves': 157,
#  'achieving': 158,
#  'achievment': 159,
#  'aching': 160,
#  'achingfantastic': 161,
#  'achingly': 162,
#  'achives': 163,
#  'acknowledge': 164,
#  'acknowledged': 165,
#  'acknowledges': 166,
#  'acknowledging': 167,
#  'ackroyd': 168,
#  'acquaintance': 169,
#  'acquaintances': 170,
#  'acquire': 171,
#  'acquired': 172,
#  'acquires': 173,
#  'acquiring': 174,
#  'acquit': 175,
#  'acquitted': 176,
#  'acrossare': 177,
#  'act': 178,
#  'acted': 179,
#  'acter': 180,
#  'acting': 181,
#  'actingand': 182,
#  'actingbefore': 183,
#  'actingdeep': 184,
#  'actingdirecting': 185,
#  'actingdirectionscripteverything': 186,
#  'actinggood': 187,
#  'actingi': 188,
#  'actingin': 189,
#  'actingit': 190,
#  'actingits': 191,
#  'actings': 192,
#  'actingscreen': 193,
#  'actingthe': 194,
#  'actingtim': 195,
#  'actingyou': 196,
#  'action': 197,
#  'actionadventure': 198,
#  'actionanyway': 199,
#  'actiondramathriller': 200,
#  'actionfans': 201,
#  'actionfilled': 202,
#  'actions': 203,
#  'actionthe': 204,
#  'actionthese': 205,
#  'activate': 206,
#  'activated': 207,
#  'active': 208,
#  'actively': 209,
#  'activities': 210,
#  'activity': 211,
#  'actor': 212,
#  'actoractress': 213,
#  'actorand': 214,
#  'actorbut': 215,
#  'actorhe': 216,
#  'actori': 217,
#  'actorits': 218,
#  'actormorgan': 219,
#  'actorproof': 220,
#  'actors': 221,
#  'actorsactresses': 222,
#  'actorsand': 223,
#  'actorscharacters': 224,
#  'actorsdirectionphotographythe': 225,
#  'actorsews': 226,
#  'actorsfinally': 227,
#  'actorsi': 228,
#  'actorsits': 229,
#  'actorsmorgan': 230,
#  'actorsr': 231,
#  'actorsrobbins': 232,
#  'actorsthis': 233,
#  'actorstim': 234,
#  'actorthe': 235,
#  'actorthere': 236,
#  'actress': 237,
#  'actresses': 238,
#  'actressmorgan': 239,
#  'actressuma': 240,
#  'acts': 241,
#  'actsespecially': 242,
#  'actthe': 243,
#  'actual': 244,
#  'actually': 245,
#  'actuallyhats': 246,
#  'actuation': 247,
#  'acutely': 248,
#  'ad': 249,
#  'adadfafdaf': 250,
#  'adam': 251,
#  'adams': 252,
#  'adapt': 253,
#  'adaptability': 254,
#  'adaptation': 255,
#  'adaptationand': 256,
#  'adaptationmasterpiecethe': 257,
#  'adaptations': 258,
#  'adaptationstim': 259,
#  'adapted': 260,
#  'adapter': 261,
#  'adapters': 262,
#  'adapting': 263,
#  'adaption': 264,
#  'adaptions': 265,
#  'adaptive': 266,
#  'adapts': 267,
#  'adapté': 268,
#  'add': 269,
#  'added': 270,
#  'addicted': 271,
#  'addiction': 272,
#  'addictive': 273,
#  'adding': 274,
#  'addition': 275,
#  'additional': 276,
#  'additionally': 277,
#  'additions': 278,
#  'addons': 279,
#  'address': 280,
#  'addressed': 281,
#  'addresses': 282,
#  'addressing': 283,
#  'adds': 284,
#  'adequate': 285,
#  'adequately': 286,
#  'adf': 287,
#  'adhd': 288,
#  'adhere': 289,
#  'adhered': 290,
#  'adherence': 291,
#  'adjacent': 292,
#  'adjectives': 293,
#  'adjust': 294,
#  'adjusted': 295,
#  'adjusting': 296,
#  'adjustment': 297,
#  'adjustments': 298,
#  'adjusts': 299,
#  'admin': 300,
#  'administration': 301,
#  'administrationthis': 302,
#  'administrative': 303,
#  'administrator': 304,
#  'admirable': 305,
#  'admiration': 306,
#  'admire': 307,
#  'admired': 308,
#  'admireif': 309,
#  'admirer': 310,
#  'admirers': 311,
#  'admires': 312,
#  'admiring': 313,
#  'admission': 314,
#  'admissiona': 315,
#  'admit': 316,
#  'admitits': 317,
#  'admitmorgan': 318,
#  'admits': 319,
#  'admittance': 320,
#  'admitted': 321,
#  'admittedly': 322,
#  'admitting': 323,
#  'adobe': 324,
#  'adopt': 325,
#  'adopted': 326,
#  'adopts': 327,
#  'adorable': 328,
#  'adorably': 329,
#  'adoration': 330,
#  'adore': 331,
#  'adored': 332,
#  'adrenalin': 333,
#  'adrenaline': 334,
#  'adrenalinefilled': 335,
#  'adrift': 336,
#  'adroitly': 337,
#  'ads': 338,
#  'adulatedthe': 339,
#  'adult': 340,
#  'adultage': 341,
#  'adulterers': 342,
#  'adulterous': 343,
#  'adultery': 344,
#  'adults': 345,
#  'advance': 346,
#  'advanced': 347,
#  'advancement': 348,
#  'advancements': 349,
#  'advances': 350,
#  'advantage': 351,
#  'advantages': 352,
#  'advent': 353,
#  'adventure': 354,
#  'adventurebut': 355,
#  'adventures': 356,
#  'adventurous': 357,
#  'adversaries': 358,
#  'adversary': 359,
#  'adverse': 360,
#  'adversities': 361,
#  'adversity': 362,
#  'adversitythe': 363,
#  'advert': 364,
#  'advertisements': 365,
#  'advertising': 366,
#  'advice': 367,
#  'advicei': 368,
#  'advicethoroughly': 369,
#  'advise': 370,
#  'advised': 371,
#  'adviser': 372,
#  'advises': 373,
#  'advisor': 374,
#  'advocate': 375,
#  'advocates': 376,
#  'aerial': 377,
#  'aerobic': 378,
#  'aesthetic': 379,
#  'aesthetically': 380,
#  'aesthetics': 381,
#  'af': 382,
#  'afda': 383,
#  'afer': 384,
#  'affair': 385,
#  'affairs': 386,
#  'affect': 387,
#  'affectations': 388,
#  'affected': 389,
#  'affecting': 390,
#  'affection': 391,
#  'affectionate': 392,
#  'affectionately': 393,
#  'affectionit': 394,
#  'affections': 395,
#  'affectionwho': 396,
#  'affects': 397,
#  'affectsits': 398,
#  'affirm': 399,
#  'affirmation': 400,
#  'affirmative': 401,
#  'affirmed': 402,
#  'affirming': 403,
#  'affliction': 404,
#  'afford': 405,
#  'affordability': 406,
#  'affordable': 407,
#  'affords': 408,
#  'afi': 409,
#  'aficionados': 410,
#  'afis': 411,
#  'aforementioned': 412,
#  'afoul': 413,
#  'afraid': 414,
#  'africa': 415,
#  'african': 416,
#  'africanamerican': 417,
#  'africathis': 418,
#  'afterall': 419,
#  'afterit': 420,
#  'afterlife': 421,
#  'afterlives': 422,
#  'aftermath': 423,
#  'afternoon': 424,
#  'afterward': 425,
#  'afterwardof': 426,
#  'aftet': 427,
#  'againandy': 428,
#  'againbut': 429,
#  'againcause': 430,
#  'againconsidering': 431,
#  'againdont': 432,
#  'againgreat': 433,
#  'againhappy': 434,
#  'againhope': 435,
#  'againi': 436,
#  'againif': 437,
#  'againim': 438,
#  'againin': 439,
#  'againit': 440,
#  'againoverall': 441,
#  'agains': 442,
#  'againstars': 443,
#  'againthanks': 444,
#  'againthe': 445,
#  'againthere': 446,
#  'againthis': 447,
#  'againtruly': 448,
#  'againwell': 449,
#  'againwhat': 450,
#  'againwhen': 451,
#  'againyou': 452,
#  'agame': 453,
#  'agape': 454,
#  'agassis': 455,
#  'age': 456,
#  'aged': 457,
#  'ageing': 458,
#  'ageits': 459,
#  'agency': 460,
#  'agenda': 461,
#  'agent': 462,
#  'agents': 463,
#  'ageold': 464,
#  'ages': 465,
#  'agesmy': 466,
#  'aggression': 467,
#  'aggressive': 468,
#  'aghast': 469,
#  'aghastit': 470,
#  'agile': 471,
#  'aging': 472,
#  'agingphysically': 473,
#  'agitated': 474,
#  'ago': 475,
#  'agoabout': 476,
#  'agoat': 477,
#  'agoi': 478,
#  'agony': 479,
#  'agothis': 480,
#  'agotim': 481,
#  'agree': 482,
#  'agreeably': 483,
#  'agreed': 484,
#  'agreei': 485,
#  'agreeing': 486,
#  'agreeits': 487,
#  'agrees': 488,
#  'agreethey': 489,
#  'agreewhat': 490,
#  'ague': 491,
#  'ah': 492,
#  'aha': 493,
#  'ahead': 494,
#  'aheadno': 495,
#  'aheadthe': 496,
#  'ahem': 497,
#  'ahold': 498,
#  'aid': 499,
#  'aided': 500,
#  'aids': 501,
#  'aim': 502,
#  'aimed': 503,
#  'aiming': 504,
#  'aimmorgan': 505,
#  'aims': 506,
#  'aint': 507,
#  'air': 508,
#  'airbrushed': 509,
#  'aired': 510,
#  'airing': 511,
#  'airings': 512,
#  'airline': 513,
#  'airs': 514,
#  'airthe': 515,
#  'airtight': 516,
#  'airtime': 517,
#  'aka': 518,
#  'akin': 519,
#  'akira': 520,
#  'al': 521,
#  'ala': 522,
#  'aladdin': 523,
#  'alarmist': 524,
#  'alas': 525,
#  'albeit': 526,
#  'albert': 527,
#  'alberts': 528,
#  'album': 529,
#  'albumis': 530,
#  'alcartaz': 531,
#  'alcatraz': 532,
#  'alcatrazthis': 533,
#  'alcatrez': 534,
#  'alcholic': 535,
#  'alcohol': 536,
#  'aldus': 537,
#  'alert': 538,
#  'alerti': 539,
#  'alertthe': 540,
#  'alertwhen': 541,
#  'alexander': 542,
#  'alexanderdumbass': 543,
#  'alexandr': 544,
#  'alfonso': 545,
#  'alfred': 546,
#  'algol': 547,
#  'algorithms': 548,
#  'alholeod': 549,
#  'ali': 550,
#  'alias': 551,
#  'alien': 552,
#  'alienation': 553,
#  'aliens': 554,
#  'alight': 555,
#  'alights': 556,
#  'aligned': 557,
#  'alike': 558,
#  'alist': 559,
#  'alive': 560,
#  'alivean': 561,
#  'aliveis': 562,
#  'alivewe': 563,
#  'alla': 564,
#  'allan': 565,
#  'alland': 566,
#  'allaround': 567,
#  'allcaps': 568,
#  'alleged': 569,
#  'allegedly': 570,
#  'allegianceandy': 571,
#  'allegoric': 572,
#  'allegorical': 573,
#  'allegorically': 574,
#  'allegories': 575,
#  'allegory': 576,
#  'allelizabethan': 577,
#  'allen': 578,
#  'allencompassing': 579,
#  'allfor': 580,
#  'allhe': 581,
#  'alli': 582,
#  'alliance': 583,
#  'allied': 584,
#  'allies': 585,
#  'allif': 586,
#  'allits': 587,
#  'allknowingincharge': 588,
#  'allmale': 589,
#  'allnew': 590,
#  'allocated': 591,
#  'allot': 592,
#  'allout': 593,
#  'alloverall': 594,
#  'allow': 595,
#  'allowable': 596,
#  'allowed': 597,
#  'allowedfurthermorethe': 598,
#  'allowing': 599,
#  'allows': 600,
#  'allpeople': 601,
#  'allpowerful': 602,
#  'allremember': 603,
#  'allround': 604,
#  'allsecondly': 605,
#  'allshawshank': 606,
#  'allsoconvenient': 607,
#  'allstar': 608,
#  'allthe': 609,
#  'allthere': 610,
#  'alltime': 611,
#  'alltimeas': 612,
#  'alltimefavorite': 613,
#  'alltimethat': 614,
#  'alltimethe': 615,
#  'alltrueit': 616,
#  'allude': 617,
#  'alluppercase': 618,
#  'allure': 619,
#  'allusion': 620,
#  'allwithin': 621,
#  'ally': 622,
#  'almighty': 623,
#  'almodovar': 624,
#  'almostperfect': 625,
#  'alonghere': 626,
#  'alongi': 627,
#  'alongside': 628,
#  'aloof': 629,
#  'aloofness': 630,
#  'alot': 631,
#  'aloud': 632,
#  'alphabet': 633,
#  'alphabets': 634,
#  'alreadyand': 635,
#  'alreadyby': 636,
#  'alreadyhowever': 637,
#  'alreadyif': 638,
#  'alreadythis': 639,
#  'alreadywatch': 640,
#  'alright': 641,
#  'alsoa': 642,
#  'alsobut': 643,
#  'alsohow': 644,
#  'alsoso': 645,
#  'alta': 646,
#  'alter': 647,
#  'alterations': 648,
#  'altered': 649,
#  'alterego': 650,
#  'altering': 651,
#  'alternately': 652,
#  'alternates': 653,
#  'alternative': 654,
#  'alternatives': 655,
#  'alters': 656,
#  'altho': 657,
#  'altman': 658,
#  'altogether': 659,
#  'altogetherthis': 660,
#  'alum': 661,
#  'alung': 662,
#  'alway': 663,
#  'alwaysby': 664,
#  'amadeus': 665,
#  'amass': 666,
#  'amateur': 667,
#  'amateurs': 668,
#  'amaze': 669,
#  'amazed': 670,
#  'amazedthe': 671,
#  'amazedthen': 672,
#  'amazement': 673,
#  'amazes': 674,
#  'amazing': 675,
#  'amazingalthough': 676,
#  'amazingand': 677,
#  'amazingespecially': 678,
#  'amazingi': 679,
#  'amazingit': 680,
#  'amazingits': 681,
#  'amazingly': 682,
#  'amazingone': 683,
#  'amazingoverall': 684,
#  'amazingplease': 685,
#  'amazingsuperb': 686,
#  'amazingtechnically': 687,
#  'amazingthis': 688,
#  'amazingwhen': 689,
#  'amazingwhere': 690,
#  'amazingwow': 691,
#  'amazon': 692,
#  'ambad': 693,
#  'ambiance': 694,
#  'ambience': 695,
#  'ambient': 696,
#  'ambiguities': 697,
#  'ambiguity': 698,
#  'ambiguous': 699,
#  'ambitious': 700,
#  'ambivalence': 701,
#  'amble': 702,
#  'amc': 703,
#  'amd': 704,
#  'amen': 705,
#  'amenities': 706,
#  'amercian': 707,
#  'america': 708,
#  'americaa': 709,
#  'americabut': 710,
#  'americamy': 711,
#  'american': 712,
#  'americanatherein': 713,
#  'americans': 714,
#  'americanswedish': 715,
#  'americas': 716,
#  'amiability': 717,
#  'amid': 718,
#  'amidst': 719,
#  'amir': 720,
#  'amiss': 721,
#  'amitabh': 722,
#  'amits': 723,
#  'amnesia': 724,
#  'amoral': 725,
#  'amounted': 726,
#  'amounting': 727,
#  'amounts': 728,
#  'amovie': 729,
#  'ample': 730,
#  'amplified': 731,
#  'amplifies': 732,
#  'amplify': 733,
#  'amuse': 734,
#  'amused': 735,
#  'amusement': 736,
#  'amusementwhen': 737,
#  'amusing': 738,
#  'amy': 739,
#  'amélie': 740,
#  'anal': 741,
#  'analogy': 742,
#  'analyse': 743,
#  'analysis': 744,
#  'analytical': 745,
#  'analytically': 746,
#  'analyze': 747,
#  'analyzes': 748,
#  'analyzing': 749,
#  'anamorphic': 750,
#  'anarchy': 751,
#  'anchors': 752,
#  'ancient': 753,
#  'andahalf': 754,
#  'andas': 755,
#  'anddy': 756,
#  'anddywe': 757,
#  'andor': 758,
#  'andreas': 759,
#  'andrew': 760,
#  'andrey': 761,
#  'andrianakos': 762,
#  'andthe': 763,
#  'andy': 764,
#  'andyaka': 765,
#  'andyandy': 766,
#  'andyduffresne': 767,
#  'andyeveryone': 768,
#  'andyeverything': 769,
#  'andyhe': 770,
#  'andyhes': 771,
#  'andyhis': 772,
#  'andyhowever': 773,
#  'andyi': 774,
#  'andymain': 775,
#  'andynormally': 776,
#  'andyredd': 777,
#  'andyreds': 778,
#  'andyrobbins': 779,
#  'andys': 780,
#  'andyshawshank': 781,
#  'andysone': 782,
#  'andystim': 783,
#  'andythat': 784,
#  'andythe': 785,
#  'andythis': 786,
#  'andythough': 787,
#  'andythus': 788,
#  'andytim': 789,
#  'andytimhe': 790,
#  'andywith': 791,
#  'anew': 792,
#  'angel': 793,
#  'angeles': 794,
#  'angels': 795,
#  'angelsshawshank': 796,
#  'anger': 797,
#  'angered': 798,
#  'angers': 799,
#  'angle': 800,
#  'angleall': 801,
#  'angleandy': 802,
#  'angles': 803,
#  'anglesand': 804,
#  'angling': 805,
#  'anglophiles': 806,
#  'angry': 807,
#  'angrymustseemoviei': 808,
#  'angst': 809,
#  'anguish': 810,
#  'animal': 811,
#  'animals': 812,
#  'animalsi': 813,
#  'animated': 814,
#  'animates': 815,
#  'animation': 816,
#  'animations': 817,
#  'animosities': 818,
#  'annals': 819,
#  'anne': 820,
#  'annes': 821,
#  'anniversary': 822,
#  'announce': 823,
#  'announced': 824,
#  'annoy': 825,
#  'annoyances': 826,
#  'annoyed': 827,
#  'annoying': 828,
#  'annoyingly': 829,
#  'annoys': 830,
#  'anointing': 831,
#  'anotherif': 832,
#  'anothers': 833,
#  'anotherthe': 834,
#  'ans': 835,
#  'answer': 836,
#  'answered': 837,
#  'answeri': 838,
#  'answering': 839,
#  'answers': 840,
#  'answerthe': 841,
#  'antagonism': 842,
#  'antagonismwhile': 843,
#  'antagonist': 844,
#  'antagonistic': 845,
#  'antagonists': 846,
#  'antes': 847,
#  'anthology': 848,
#  'anti': 849,
#  'antichristian': 850,
#  'anticipated': 851,
#  'anticipates': 852,
#  'anticipating': 853,
#  'anticipation': 854,
#  'antics': 855,
#  'antidepression': 856,
#  'antiinstitutional': 857,
#  'antisocial': 858,
#  'antithesis': 859,
#  'antivillain': 860,
#  'antonym': 861,
#  'ants': 862,
#  'antz': 863,
#  'anxiety': 864,
#  'anxietytensionetc': 865,
#  'anxious': 866,
#  'anxiously': 867,
#  'anybody': 868,
#  'anybodygrade': 869,
#  'anybodys': 870,
#  'anyday': 871,
#  'anyi': 872,
#  'anymore': 873,
#  'anymorea': 874,
#  'anymorebest': 875,
#  'anymorefrank': 876,
#  'anymorethe': 877,
#  'anymorethis': 878,
#  'anyonemaybe': 879,
#  'anyones': 880,
#  'anyplace': 881,
#  'anythingand': 882,
#  'anythingmorgan': 883,
#  'anythingoh': 884,
#  'anythingthe': 885,
#  'anytime': 886,
#  'anywaymind': 887,
#  'anywayred': 888,
#  'anyways': 889,
#  'anywaysa': 890,
#  'anywaysfirst': 891,
#  'anywaysif': 892,
#  'anywaythe': 893,
#  'anywhereeven': 894,
#  'anywherewriter': 895,
#  'ap': 896,
#  'apart': 897,
#  'apartment': 898,
#  'apartments': 899,
#  'apartthe': 900,
#  'apathetic': 901,
#  'apathetically': 902,
#  'apathy': 903,
#  'apes': 904,
#  'apexes': 905,
#  'apiece': 906,
#  'aplomb': 907,
#  'apocalypse': 908,
#  'apocalyptic': 909,
#  'apologies': 910,
#  'apologize': 911,
#  'apon': 912,
#  'apos': 913,
#  'appaling': 914,
#  'appalled': 915,
#  'appalling': 916,
#  'apparent': 917,
#  'apparenti': 918,
#  'apparently': 919,
#  'appeal': 920,
#  'appealbut': 921,
#  'appealed': 922,
#  'appealing': 923,
#  'appeals': 924,
#  'appealutter': 925,
#  'appear': 926,
#  'appearance': 927,
#  'appearancefor': 928,
#  'appearances': 929,
#  'appeared': 930,
#  'appearing': 931,
#  'appears': 932,
#  'appeasing': 933,
#  'appetite': 934,
#  'applaud': 935,
#  'applauded': 936,
#  'applauding': 937,
#  'applause': 938,
#  'applausewatching': 939,
#  'apples': 940,
#  'appliance': 941,
#  'applicable': 942,
#  'application': 943,
#  'applications': 944,
#  'applied': 945,
#  'applies': 946,
#  'apply': 947,
#  'applying': 948,
#  'appointed': 949,
#  'appoints': 950,
#  'apposite': 951,
#  'appreciate': 952,
#  'appreciated': 953,
#  'appreciatedthis': 954,
#  'appreciates': 955,
#  'appreciating': 956,
#  'appreciatingas': 957,
#  'appreciation': 958,
#  'appreciationif': 959,
#  'appreciative': 960,
#  'apprehension': 961,
#  'approach': 962,
#  'approachable': 963,
#  'approached': 964,
#  'approaches': 965,
#  'approaching': 966,
#  'appropriate': 967,
#  'appropriategame': 968,
#  'appropriately': 969,
#  'appropriatewhen': 970,
#  'appropriations': 971,
#  'approval': 972,
#  'approve': 973,
#  'approved': 974,
#  'approximate': 975,
#  'approximately': 976,
#  'april': 977,
#  'apt': 978,
#  'aptly': 979,
#  'arabia': 980,
#  'arararar': 981,
#  'arasinda': 982,
#  'arbitrary': 983,
#  'arbitrator': 984,
#  'arc': 985,
#  'arch': 986,
#  'arches': 987,
#  'archetypal': 988,
#  'archetypes': 989,
#  'architecture': 990,
#  'archive': 991,
#  'arcs': 992,
#  'ardent': 993,
#  'area': 994,
#  'areas': 995,
#  'arego': 996,
#  'arei': 997,
#  'aremesmerized': 998,
#  'arena': 999,
#  ...}

# %%
word_weight_positive={}
cnt=0
for i in range(total_topics):
    word_topic=lda.print_topic(i).split('+')
    j=0
    for word_probab in word_topic:
        val,wor=word_probab.split('*')        
        wor=str(wor)
        #print(wor)
        y=len(wor)
        if j==len(word_topic)-1:
            wor = wor[1:y-1]
        else:
            wor = wor[1:y-2]
        #print(wor)
        if wor not in word_weight_positive:
            word_weight_positive[wor]=cnt
            cnt+=1
            
        
        j=j+1

# %%
print(len(word_weight_positive))
# Out:
# 345

# %%
import nltk
from nltk.corpus import wordnet
nltk.download('wordnet')
print(lda.print_topic(5))
# Out:
# 0.053*"movie" + 0.022*"movies" + 0.020*"love" + 0.018*"funny" + 0.015*"lot" + 0.014*"time" + 0.014*"suggestion" + 0.014*"cool" + 0.010*"andy" + 0.008*"just"
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/shivashish/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
train_size = len(df2.index)
test_size = len(df3.index)
no_of_words = len(word_weight_positive)
X_train = np.zeros((train_size,no_of_words))
X_test = np.zeros((test_size,no_of_words))
Y_test = np.zeros(test_size)

# %%
print(data_clean.iloc[10][0])
# Out:
# the next morning the inmates learn that fat ass died in the infirmary because the prison doctor had been out for the night

# %%
for i in range(train_size):
    s = set(data_clean.iloc[i][0].split(' '))
    for wor in s:
        if wor not in word_weight_positive:
            flag=0
            for syn in wordnet.synsets(wor): 
                for l in syn.lemmas(): 
                    temp_word = l.name()
                    if temp_word in word_weight_positive:
                        flag=1
                        break
                if flag==1:
                    break
            if flag==1:
                index = word_weight_positive[temp_word]
                ind2 = word_dict[temp_word]
                X_train[i][index]+=data_dtm.iloc[i][ind2]
        else :
            index = word_weight_positive[wor]
            ind2 = word_dict[wor]
            X_train[i][index]+=data_dtm.iloc[i][ind2]

# %%
for i in range(test_size):
    if i%20 == 0:
        print(i)
    s = set(data_clean2.iloc[i][0].split(' '))
    for wor in s:
        if wor in word_dict2:
            if wor not in word_weight_positive:
                flag=0
                for syn in wordnet.synsets(wor): 
                    for l in syn.lemmas(): 
                        temp_word = l.name()
                        if temp_word in word_weight_positive:
                            flag=1
                            break
                    if flag==1:
                        break
                if flag==1:
                    index = word_weight_positive[temp_word]
                    ind2 = word_dict2[wor]
                    X_test[i][index]+=data_dtm2.iloc[i][ind2]
            else :
                index = word_weight_positive[wor]
                ind2 = word_dict2[wor]
                X_test[i][index]+=data_dtm2.iloc[i][ind2]
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860
# 880
# 900
# 920
# 940
# 960
# 980
# 1000
# 1020
# 1040
# 1060
# 1080
# 1100
# 1120
# 1140
# 1160
# 1180
# 1200
# 1220
# 1240
# 1260
# 1280
# 1300
# 1320
# 1340
# 1360
# 1380
# 1400
# 1420
# 1440
# 1460
# 1480
# 1500
# 1520
# 1540
# 1560
# 1580
# 1600
# 1620
# 1640
# 1660
# 1680
# 1700
# 1720
# 1740
# 1760
# 1780
# 1800
# 1820
# 1840
# 1860
# 1880
# 1900
# 1920
# 1940
# 1960
# 1980
# 2000
# 2020
# 2040
# 2060
# 2080
# 2100
# 2120
# 2140
# 2160
# 2180
# 2200
# 2220
# 2240
# 2260
# 2280
# 2300
# 2320
# 2340
# 2360
# 2380
# 2400
# 2420
# 2440
# 2460
# 2480
# 2500
# 2520
# 2540
# 2560
# 2580
# 2600
# 2620
# 2640
# 2660
# 2680
# 2700
# 2720
# 2740
# 2760
# 2780
# 2800
# 2820
# 2840
# 2860
# 2880
# 2900
# 2920
# 2940
# 2960
# 2980
# 3000
# 3020
# 3040
# 3060
# 3080
# 3100
# 3120
# 3140
# 3160
# 3180
# 3200
# 3220
# 3240
# 3260
# 3280
# 3300
# 3320
# 3340
# 3360
# 3380
# 3400
# 3420
# 3440
# 3460
# 3480
# 3500
# 3520
# 3540
# 3560
# 3580
# 3600
# 3620
# 3640
# 3660

# %%
for i in range(test_size):
    Y_test[i]=df3.iloc[i]["is_spoiler"]

# %%
from sklearn.svm import OneClassSVM
lpu_model = OneClassSVM(gamma='auto').fit(X_train)
Y_out = lpu_model.predict(X_test)

# %%
wrong=0
for i in range(len(Y_out)):
    if Y_out[i]==-1 and Y_test[i]==1:
        wrong+=1
    else :
        if Y_out[i]==1 and Y_test[i]==0:
            wrong+=1
print(wrong/len(Y_out))
# Out:
# 0.5632340890467086
