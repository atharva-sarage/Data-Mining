# %%
import pandas as pd
import re
import string
import sklearn
import csv

# %%
dataset_file="dataset_godfather.csv"
synopsis_file='synopsis_godfather.txt'
df = pd.read_csv(dataset_file)
file = open(synopsis_file,"r")
text=file.read()
sentences = text.split('. ')
   
df2 = pd.DataFrame(sentences, columns=["synopsis"])
df2.to_csv('synopsis3.csv', index=False)
# print(df2.head())
df_pos=df.loc[df['is_spoiler'] == True]
df_neg=df.loc[df['is_spoiler'] == False]
pos_size=min(1000,df_pos.shape[0])
neg_size=min(1500,df_neg.shape[0])
print(pos_size,neg_size)
train_size=0.8*(pos_size+neg_size)
test_size=0.2*(pos_size+neg_size)
df_train_pos=df_pos.loc[:0.8*pos_size,:]
df_test_pos=df_pos.loc[0.8*pos_size+1:,:]
df_train_neg=df_neg.loc[:0.8*neg_size,:]
df_test_neg=df_neg.loc[0.8*neg_size+1:,:]
# df_train_neg.to_csv('train.csv', index=False)
frames_train=[df_train_pos,df_train_neg]
frames_test=[df_test_pos,df_test_neg]
df_train=pd.concat(frames_train)
df_test=pd.concat(frames_test)
df_train.to_csv('train.csv', index=False)
df_test.to_csv('test.csv', index=False)
# Out:
# 420 1500

# %%
print(df.head())
# Out:
#    Unnamed: 0  is_spoiler                                            Comment  \
# 0       22353        True  This is without a doubt the movie I have seen ...
# 1       22354        True  What I find completely ridiculous is why this ...
# 2       22355        True  Starring: Tom Hanks, Robin Wright, Gary Sinise...
# 3       22356        True  FORREST GUMP (1994) **** Tom Hanks, Sally Fiel...
# 4       22357        True  i don't usually watch many family type movies,...
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
total_size=len(df.index)

# %%
index=[]
for i in range(len(df_train.index)):
    index.append("Comment "+str(i))
#df.insert(loc=0,column='index',value=index)
df_train['index']=index
df_train.set_index('index', inplace=True)

index2=[]
for i in range(len(df2.index)):
    index2.append("Comment "+str(i))
#df.insert(loc=0,column='index',value=index)
df2['index']=index2
df2.set_index('index', inplace=True)
df2
# Out:
#                                                       synopsis
# index
# Comment 0    In late summer 1945, guests are gathered for t...
# Comment 1    Vito (Marlon Brando), the head of the Corleone...
# Comment 2    The Don is disappointed in Bonasera, who'd avo...
# Comment 3    The Don's wife is godmother to Bonasera's sham...
# Comment 4    The Don agrees to have his men punish the youn...
# Comment 5    The wedding scene serves as critical expositio...
# Comment 6    Fredo (John Cazale), Michael's next older brot...
# Comment 7    Santino, who is nicknamed Sonny (James Caan), ...
# Comment 8    Tom Hagen is not related to the family by bloo...
# Comment 9    Now a talented attorney, Tom is being groomed ...
# Comment 10   Jack Woltz (John Marley), the head of the stud...
# Comment 11   Woltz holds a grudge because Fontane seduced a...
# Comment 12   Woltz is persuaded to give Johnny the role, ho...
# Comment 13   He pulls back the sheets and finds himself in ...
# Comment 14   (A deleted scene from the film implies that Lu...
# Comment 15   He asks Don Corleone for financing as well as ...
# Comment 16   Despite the huge profit to be made, Vito Corle...
# Comment 17   The Don's eldest son, Sonny, who had earlier u...
# Comment 18   His father, angry at Sonny's dissension in a n...
# Comment 19   Don Corleone then dispatches Luca Brasi to inf...
# Comment 20   During the meeting, while Brasi is bent over t...
# Comment 21   Fredo Corleone had been assigned driving and p...
# Comment 22   Fredo proves to be ineffectual, fumbling with ...
# Comment 23   When Sonny hears about the Don being shot and ...
# Comment 24   Castellano) to find Paulie and bring him to th...
# Comment 25   When Tom is released, Sollozzo gets word that ...
# Comment 26   He angrily tells Tom to persuade Sonny to acce...
# Comment 27   They refuse, and instead send Sonny "a Sicilia...
# Comment 28   Sonny wants to "go to the mattresses" -- set u...
# Comment 29   On their way back from Manhattan, Clemenza has...
# ...                                                        ...
# Comment 71   With Don Vito semi-retired, Sonny dead, and mi...
# Comment 72   He plans to move the family operations to Neva...
# Comment 73   Michael further promises Connie's husband, Car...
# Comment 74   Tom Hagen has been removed as consigliere and ...
# Comment 75   Privately, Hagen inquires about his change in ...
# Comment 76   Don Vito explains to Hagen that Michael is act...
# Comment 77   After the Don's attempted assassination, Fredo...
# Comment 78   Michael arrogantly offers to buy out Greene bu...
# Comment 79   Greene believes the Corleones are weak and tha...
# Comment 80   As Moe and Michael heatedly negotiate, Fredo s...
# Comment 81   Afterward, Michael warns Fredo to never again ...
# Comment 82   In a private moment, Vito explains his expecta...
# Comment 83   Vito also reveals that he had never really int...
# Comment 84   Some months later, Vito collapses and dies whi...
# Comment 85   At the burial, Tessio conveys a proposal for a...
# Comment 86   Michael agrees and seizes the opportunity to e...
# Comment 87   The murders occur simultaneously during the ce...
# Comment 88   Regis Hotel and shot dead by soldier Willi Cic...
# Comment 89   Instead, he is surrounded by Willi Cicci and o...
# Comment 90   Realizing that Michael has uncovered his betra...
# Comment 91   Tessio is driven away and never seen again (it...
# Comment 92   (The hitmen who killed Sonny were the core mem...
# Comment 93   He hands Carlo a plane ticket to exile in Las ...
# Comment 94   However, when Carlo gets into a car headed for...
# Comment 95   She accuses him of murdering Carlo in retribut...
# Comment 96   After Connie is removed from the house, Kay qu...
# Comment 97   She insists, and Michael outright lies, reassu...
# Comment 98                    Kay believes him and is relieved
# Comment 99   The film ends with Clemenza and new caporegime...
# Comment 100  Clemenza kisses Michael's hand and greets him ...
#
# [101 rows x 1 columns]

# %%
#print(index)

# %%
def clean_text_round1(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text
round1 = lambda x: clean_text_round1(x)

# %%
data_clean = pd.DataFrame(df_train.review_text.apply(round1))
data_clean2 = pd.DataFrame(df2.synopsis.apply(round1))
data_clean
# Out:
#                                                     review_text
# index
# Comment 0     rather than concentrating on everything that i...
# Comment 1     the godfather is one of the few films in which...
# Comment 2     this is by far the best movie ever to give a p...
# Comment 3     the godfather simply put is one of the greates...
# Comment 4     the godfather is a huge piece of film entertai...
# Comment 5     the godfather is one of the very few films tha...
# Comment 6     before the godfather came out in  the gangster...
# Comment 7     some people have called this one of the best m...
# Comment 8     think epic novel crossed with mafia speakimagi...
# Comment 9     the godfather is not just a crime film its muc...
# Comment 10    incredible with the epic soundtrack characters...
# Comment 22       0        0     0      0     0      0         0
# Comment 23       0        0     0      0     0      0         0
# Comment 24       0        0     0      0     0      0         0
# Comment 25       0        0     0      0     0      0         0
# Comment 26       0        0     0      0     0      0         0
# Comment 27       0        1     0      0     0      0         0
# Comment 28       0        0     0      0     0      0         0
# Comment 29       0        0     0      0     0      0         0
# ...            ...      ...   ...    ...   ...    ...       ...
# Comment 71       0        0     0      2     0      0         0
# Comment 72       0        0     0      0     1      0         0
# Comment 73       0        0     0      0     0      0         0
# Comment 74       0        0     0      0     0      0         0
# Comment 75       0        0     0      0     0      0         0
# Comment 76       0        0     1      0     0      0         0
# Comment 77       0        0     0      0     0      0         0
# Comment 78       0        0     0      0     0      0         0
# Comment 79       0        0     0      0     0      0         0
# Comment 80       0        0     0      0     0      0         0
# Comment 81       0        0     0      0     0      0         0
# Comment 82       0        0     0      0     0      0         0
# Comment 83       0        0     0      0     0      0         1
# Comment 84       0        0     0      0     0      1         0
# Comment 85       0        0     0      0     0      0         0
# Comment 86       0        0     0      0     0      0         0
# Comment 87       0        0     0      0     0      0         0
# Comment 88       0        0     0      0     0      0         0
# Comment 89       0        0     0      0     0      0         0
# Comment 90       0        0     0      0     0      0         0
# Comment 91       0        0     0      0     0      0         0
# Comment 92       0        0     0      0     0      0         0
# Comment 93       0        0     0      0     0      0         0
# Comment 94       0        0     0      0     0      0         0
# Comment 95       0        0     0      0     0      0         0
# Comment 96       0        0     0      0     0      0         0
# Comment 97       0        0     0      0     0      0         0
# Comment 98       0        0     0      0     0      0         0
# Comment 99       0        0     0      0     0      0         0
# Comment 100      0        0     0      0     0      0         0
#
# [101 rows x 948 columns]

# %%
import numpy as np
from gensim import matutils, models
import scipy.sparse

# %%
id_word_dict={}
for i in range(len(data_dtm.columns)):
    id_word_dict[i]=data_dtm.columns[i]
print(id_word_dict)
tdm = data_dtm.transpose()

id_word_dict2={}
for i in range(len(data_dtm2.columns)):
    id_word_dict2[i]=data_dtm2.columns[i]
print(id_word_dict2)
tdm2 = data_dtm2.transpose()
# Out:
# {0: 'abandon', 1: 'abbe', 2: 'abduction', 3: 'abe', 4: 'abhor', 5: 'abhorrence', 6: 'abides', 7: 'abiding', 8: 'abilities', 9: 'ability', 10: 'abject', 11: 'able', 12: 'ably', 13: 'abnegation', 14: 'abott', 15: 'abound', 16: 'aboutall', 17: 'aboutcoppolas', 18: 'abouthe', 19: 'aboutsecondly', 20: 'aboutthe', 21: 'aboutthis', 22: 'abouttruly', 23: 'abraham', 24: 'abrasive', 25: 'abroad', 26: 'abroadfrancis', 27: 'abroadone', 28: 'abrupt', 29: 'abruptly', 30: 'absence', 31: 'absent', 32: 'absolute', 33: 'absolutely', 34: 'absorb', 35: 'absorbed', 36: 'absorbing', 37: 'absorbingthe', 38: 'absorbs', 39: 'absurd', 40: 'absurdity', 41: 'absurdly', 42: 'abuse', 43: 'abused', 44: 'abuses', 45: 'abusing', 46: 'abusive', 47: 'abut', 48: 'abyss', 49: 'acadamy', 50: 'academy', 51: 'academyaward', 52: 'acadia', 53: 'accent', 54: 'accents', 55: 'accentsthe', 56: 'accentuates', 57: 'accept', 58: 'acceptable', 59: 'acceptance', 60: 'accepted', 61: 'accepts', 62: 'accessible', 63: 'accessiblewhile', 64: 'accident', 65: 'accidental', 66: 'acclaim', 67: 'acclaimed', 68: 'accolades', 69: 'accompanied', 70: 'accompanying', 71: 'accomplices', 72: 'accomplish', 73: 'accomplished', 74: 'accomplishes', 75: 'accomplishment', 76: 'accomplishments', 77: 'accord', 78: 'according', 79: 'account', 80: 'accounts', 81: 'accredited', 82: 'accumulating', 83: 'accuracy', 84: 'accurate', 85: 'accurately', 86: 'accusations', 87: 'accuse', 88: 'accuses', 89: 'accustomed', 90: 'ace', 91: 'aces', 92: 'achieve', 93: 'achieved', 94: 'achievement', 95: 'achievements', 96: 'achieves', 97: 'achieving', 98: 'acknowledge', 99: 'acknowledged', 100: 'acotrs', 101: 'acquaintances', 102: 'acquainted', 103: 'acquired', 104: 'acquiring', 105: 'act', 106: 'acted', 107: 'actedmarlon', 108: 'acting', 109: 'actinghistory', 110: 'actingi', 111: 'actingnino', 112: 'actingoh', 113: 'actingpacino', 114: 'actings', 115: 'actingthe', 116: 'actingyou', 117: 'action', 118: 'actionadventure', 119: 'actiondriven', 120: 'actionentertainment', 121: 'actions', 122: 'active', 123: 'actively', 124: 'activities', 125: 'activity', 126: 'actnowthinklater', 127: 'actor', 128: 'actoractress', 129: 'actorfinally', 130: 'actoritis', 131: 'actormarlon', 132: 'actors', 133: 'actorsactress', 134: 'actorsall', 135: 'actorsmarlon', 136: 'actorsthe', 137: 'actorsthis', 138: 'actorsyou', 139: 'actress', 140: 'actresses', 141: 'acts', 142: 'actsdirected', 143: 'actsinitially', 144: 'actual', 145: 'actually', 146: 'actuallyi', 147: 'actuation', 148: 'actwhen', 149: 'acute', 150: 'acutely', 151: 'ad', 152: 'ada', 153: 'adamant', 154: 'adams', 155: 'adamscorleone', 156: 'adamsdiane', 157: 'adamsmichaels', 158: 'adapt', 159: 'adaptation', 160: 'adaptationreplay', 161: 'adaptations', 162: 'adapted', 163: 'adapting', 164: 'adaption', 165: 'adapts', 166: 'add', 167: 'added', 168: 'addict', 169: 'addicted', 170: 'addiction', 171: 'addictions', 172: 'addictive', 173: 'adding', 174: 'addition', 175: 'additional', 176: 'additionally', 177: 'address', 178: 'addressed', 179: 'addressing', 180: 'adds', 181: 'adept', 182: 'adequate', 183: 'adhere', 184: 'adherence', 185: 'adjusted', 186: 'admirable', 187: 'admirably', 188: 'admiration', 189: 'admire', 190: 'admired', 191: 'admirers', 192: 'admiring', 193: 'admit', 194: 'admitoh', 195: 'admitted', 196: 'admittedly', 197: 'admitting', 198: 'adopted', 199: 'adoptedthe', 200: 'adoption', 201: 'adoptive', 202: 'adorable', 203: 'adoration', 204: 'adore', 205: 'adored', 206: 'adoring', 207: 'adrenaline', 208: 'adrian', 209: 'adulatory', 210: 'adult', 211: 'adultery', 212: 'adults', 213: 'advance', 214: 'advanced', 215: 'advances', 216: 'advantage', 217: 'advantages', 218: 'advent', 219: 'adventure', 220: 'adventures', 221: 'adversaries', 222: 'adversary', 223: 'adverse', 224: 'advertised', 225: 'advice', 226: 'adviceread', 227: 'advisable', 228: 'advise', 229: 'advised', 230: 'adviser', 231: 'advisers', 232: 'adviserthe', 233: 'advisors', 234: 'advocate', 235: 'advocateboth', 236: 'ad ...
# {0: 'abducts', 1: 'abe', 2: 'absence', 3: 'abuse', 4: 'abuses', 5: 'accept', 6: 'accepts', 7: 'accompanied', 8: 'according', 9: 'accusation', 10: 'accuses', 11: 'acquaintance', 12: 'acting', 13: 'adams', 14: 'admit', 15: 'advances', 16: 'advantage', 17: 'advice', 18: 'affair', 19: 'afterward', 20: 'agree', 21: 'agrees', 22: 'aimlessly', 23: 'airport', 24: 'al', 25: 'alex', 26: 'alibi', 27: 'allied', 28: 'allout', 29: 'allow', 30: 'altercation', 31: 'ambassador', 32: 'ambush', 33: 'ambushed', 34: 'america', 35: 'american', 36: 'amerigo', 37: 'amused', 38: 'anecdotes', 39: 'angeles', 40: 'angelo', 41: 'angrily', 42: 'angry', 43: 'answer', 44: 'anthony', 45: 'apartments', 46: 'apollonia', 47: 'appear', 48: 'approached', 49: 'area', 50: 'argue', 51: 'argues', 52: 'arrange', 53: 'arranged', 54: 'arrival', 55: 'arrive', 56: 'arrives', 57: 'arriving', 58: 'arrogantly', 59: 'ask', 60: 'asked', 61: 'asks', 62: 'assassin', 63: 'assassinated', 64: 'assassination', 65: 'assets', 66: 'assigned', 67: 'associate', 68: 'associates', 69: 'assurances', 70: 'assures', 71: 'attempt', 72: 'attempted', 73: 'attend', 74: 'attorney', 75: 'authorities', 76: 'avoided', 77: 'away', 78: 'backed', 79: 'baker', 80: 'baptism', 81: 'bar', 82: 'barzini', 83: 'barzinis', 84: 'bathroom', 85: 'beat', 86: 'beaten', 87: 'beats', 88: 'beautiful', 89: 'bed', 90: 'bedroom', 91: 'beds', 92: 'befriended', 93: 'begins', 94: 'behavior', 95: 'believes', 96: 'bent', 97: 'betrayal', 98: 'better', 99: 'bigger', 100: 'bit', 101: 'blood', 102: 'bloody', 103: 'bluff', 104: 'body', 105: 'bodyguard', 106: 'bodyguards', 107: 'bonasera', 108: 'bonaseras', 109: 'bond', 110: 'booth', 111: 'boss', 112: 'brando', 113: 'brasi', 114: 'brasis', 115: 'break', 116: 'breaking', 117: 'breaks', 118: 'bridesmaids', 119: 'bright', 120: 'bring', 121: 'bringing', 122: 'brother', 123: 'bruise', 124: 'bruno', 125: 'brutal', 126: 'brutalizing', 127: 'brutally', 128: 'building', 129: 'built', 130: 'bulletproof', 131: 'burial', 132: 'business', 133: 'button', 134: 'buy', 135: 'caan', 136: 'cake', 137: 'called', 138: 'calls', 139: 'calo', 140: 'caporegimes', 141: 'captain', 142: 'captains', 143: 'car', 144: 'career', 145: 'carlo', 146: 'carloads', 147: 'carlos', 148: 'carry', 149: 'cars', 150: 'casino', 151: 'cast', 152: 'castellano', 153: 'causeway', 154: 'cazale', 155: 'ceasefire', 156: 'celebration', 157: 'ceremony', 158: 'change', 159: 'character', 160: 'characters', 161: 'charge', 162: 'cheek', 163: 'chief', 164: 'child', 165: 'children', 166: 'cicci', 167: 'cigarette', 168: 'citizen', 169: 'citti', 170: 'civilian', 171: 'clampdown', 172: 'clean', 173: 'clemenza', 174: 'closed', 175: 'collapses', 176: 'come', 177: 'competition', 178: 'complain', 179: 'completely', 180: 'compound', 181: 'confidence', 182: 'conflict', 183: 'confronts', 184: 'congratulatory', 185: 'connie', 186: 'connies', 187: 'consider', 188: 'considered', 189: 'consigliere', 190: 'contact', 191: 'conte', 192: 'controlled', 193: 'converse', 194: 'conveys', 195: 'convinces', 196: 'core', 197: 'corleone', 198: 'corleones', 199: 'corrado', 200: 'corrupt', 201: 'costello', 202: 'costly', 203: 'counselor', 204: 'countryside', 205: 'couple', 206: 'couples', 207: 'course', 208: 'court', 209: 'covering', 210: 'crime', 211: 'criminal', 212: 'critical', 213: 'crowded', 214: 'cuneo', 215: 'daughter', 216: 'daughters', 217: 'day', 218: 'dead', 219: 'deal', 220: 'dealings', 221: 'death', 222: 'decades', 223: 'decision', 224: 'decorated', 225: 'deduces', 226: 'deleted', 227: 'delight', 228: 'denies', 229: 'despite', 230: 'detectives', 231: 'diane', 232: 'dies', 233: 'different', 234: 'dimwitted', 235: 'dining', 236: 'dinner', 237: 'disappointed', 238: 'disarms', 239: 'discovers', 240: 'disguised', 241: 'disintegrating', 242: 'disloyalty', 243: 'dispatched', 244: 'dispatches', 245: 'disputes', 246: 'dissension', 247: 'distraught', 248: 'distributing', 249: 'does', 250: 'doesnt', 251: 'domestic', 252: 'don', 253: 'dons', 254: 'door', 255: 'draining ...

# %%
sparse_counts = scipy.sparse.csr_matrix(tdm)
corpus = matutils.Sparse2Corpus(sparse_counts)

sparse_counts2 = scipy.sparse.csr_matrix(tdm2)
corpus2 = matutils.Sparse2Corpus(sparse_counts2)

# %%
total_topics=20
lda = models.LdaModel(corpus=corpus, id2word=id_word_dict, num_topics=total_topics, passes=50)
#lda.print_topics()
lda2 = models.LdaModel(corpus=corpus2, id2word=id_word_dict2, num_topics=total_topics, passes=50)

#lda =  models.wrappers.LdaMallet('/Users/atharva/mallet-2.0.7/bin/mallet',corpus=corpus, num_topics=10, id2word=id_word_dict)

# %%
lda.print_topics()
#lda2.print_topics()
# Out:
# [(0,
#   '0.006*"challenged" + 0.006*"mentally" + 0.004*"real" + 0.003*"university" + 0.003*"worked" + 0.003*"players" + 0.003*"redemption" + 0.003*"shawshank" + 0.003*"successes" + 0.003*"football"'),
#  (1,
#   '0.025*"gump" + 0.022*"forrest" + 0.015*"film" + 0.013*"hanks" + 0.012*"life" + 0.011*"tom" + 0.010*"movie" + 0.008*"story" + 0.006*"watch" + 0.006*"best"'),
#  (2,
#   '0.030*"gump" + 0.024*"forrest" + 0.018*"film" + 0.013*"hanks" + 0.011*"tom" + 0.009*"life" + 0.009*"jenny" + 0.008*"movie" + 0.008*"man" + 0.008*"story"'),
#  (3,
#   '0.017*"forrest" + 0.016*"movie" + 0.010*"gump" + 0.010*"just" + 0.010*"life" + 0.009*"like" + 0.009*"good" + 0.009*"way" + 0.008*"film" + 0.008*"best"'),
#  (4,
#   '0.026*"movie" + 0.018*"forrest" + 0.016*"gump" + 0.010*"like" + 0.009*"story" + 0.009*"hanks" + 0.007*"history" + 0.006*"life" + 0.006*"american" + 0.006*"just"'),
#  (5,
#   '0.023*"film" + 0.018*"movie" + 0.010*"gump" + 0.008*"hanks" + 0.008*"just" + 0.007*"great" + 0.007*"forrest" + 0.007*"fiction" + 0.007*"films" + 0.006*"tom"'),
#  (6,
#   '0.024*"movie" + 0.019*"forrest" + 0.012*"gump" + 0.012*"just" + 0.008*"like" + 0.007*"best" + 0.006*"dont" + 0.006*"love" + 0.006*"stupid" + 0.006*"story"'),
#  (7,
#   '0.016*"movie" + 0.010*"film" + 0.007*"tom" + 0.007*"hanks" + 0.007*"great" + 0.005*"love" + 0.005*"films" + 0.005*"watch" + 0.005*"just" + 0.004*"like"'),
#  (8,
#   '0.011*"film" + 0.010*"people" + 0.010*"life" + 0.006*"really" + 0.006*"gump" + 0.006*"movie" + 0.005*"truly" + 0.005*"dan" + 0.005*"god" + 0.005*"learn"'),
#  (9,
#   '0.036*"movie" + 0.015*"film" + 0.014*"like" + 0.011*"dont" + 0.009*"great" + 0.008*"best" + 0.008*"people" + 0.008*"forrest" + 0.007*"gump" + 0.007*"hanks"'),
#  (10,
#   '0.054*"forrest" + 0.025*"jenny" + 0.019*"gump" + 0.012*"life" + 0.012*"movie" + 0.011*"film" + 0.010*"forrests" + 0.009*"bubba" + 0.009*"war" + 0.008*"dan"'),
#  (11,
#   '0.053*"movie" + 0.021*"life" + 0.021*"gump" + 0.020*"forrest" + 0.016*"like" + 0.012*"film" + 0.012*"time" + 0.011*"just" + 0.011*"hanks" + 0.009*"tom"'),
#  (12,
#   '0.016*"film" + 0.010*"like" + 0.009*"forrest" + 0.009*"people" + 0.008*"gump" + 0.007*"story" + 0.007*"life" + 0.007*"hanks" + 0.007*"meets" + 0.006*"just"'),
#  (13,
#   '0.026*"movie" + 0.025*"forrest" + 0.014*"hanks" + 0.013*"gump" + 0.010*"tom" + 0.009*"life" + 0.009*"story" + 0.009*"best" + 0.008*"great" + 0.008*"time"'),
#  (14,
#   '0.028*"forrest" + 0.027*"film" + 0.020*"life" + 0.015*"gump" + 0.012*"movie" + 0.011*"like" + 0.008*"people" + 0.007*"love" + 0.006*"time" + 0.006*"jenny"'),
#  (15,
#   '0.019*"film" + 0.009*"gump" + 0.008*"forest" + 0.006*"movie" + 0.006*"like" + 0.006*"history" + 0.006*"want" + 0.005*"character" + 0.005*"dont" + 0.005*"war"'),
#  (16,
#   '0.017*"film" + 0.007*"forrest" + 0.006*"hanks" + 0.006*"like" + 0.005*"movie" + 0.005*"good" + 0.004*"life" + 0.004*"american" + 0.003*"message" + 0.003*"history"'),
#  (17,
#   '0.076*"movie" + 0.023*"watch" + 0.016*"movies" + 0.015*"time" + 0.014*"film" + 0.013*"best" + 0.012*"hanks" + 0.012*"forrest" + 0.012*"tom" + 0.012*"love"'),
#  (18,
#   '0.024*"forrest" + 0.022*"film" + 0.022*"best" + 0.021*"gump" + 0.017*"hanks" + 0.013*"tom" + 0.009*"movie" + 0.008*"like" + 0.008*"life" + 0.008*"zemeckis"'),
#  (19,
#   '0.016*"film" + 0.008*"like" + 0.007*"life" + 0.006*"feel" + 0.005*"way" + 0.005*"forrest" + 0.004*"actually" + 0.004*"think" + 0.004*"good" + 0.004*"blogger"')]

# %%
lda2.print_topics()
# Out:
# [(0,
#   '0.050*"invests" + 0.050*"money" + 0.050*"dan" + 0.050*"rest" + 0.050*"computer" + 0.050*"forrest" + 0.050*"secure" + 0.050*"life" + 0.050*"financially" + 0.050*"apple"'),
#  (1,
#   '0.079*"school" + 0.041*"ends" + 0.041*"jenny" + 0.041*"afterward" + 0.041*"son" + 0.041*"waiting" + 0.041*"bus" + 0.041*"father" + 0.041*"dies" + 0.041*"forrests"'),
#  (2,
#   '0.029*"life" + 0.029*"day" + 0.029*"times" + 0.029*"meets" + 0.029*"regularly" + 0.029*"veneration" + 0.029*"school" + 0.029*"narration" + 0.029*"bus" + 0.029*"different"'),
#  (3,
#   '0.005*"pingpong" + 0.005*"patrol" + 0.005*"popularity" + 0.005*"playing" + 0.005*"platoon" + 0.005*"probably" + 0.005*"picks" + 0.005*"paddles" + 0.005*"pages" + 0.005*"proposes"'),
#  (4,
#   '0.046*"ability" + 0.046*"football" + 0.046*"college" + 0.046*"scholarship" + 0.046*"run" + 0.046*"braces" + 0.046*"lightning" + 0.046*"having" + 0.046*"discarded" + 0.046*"gets"'),
#  (5,
#   '0.050*"love" + 0.050*"sleeping" + 0.050*"obliged" + 0.050*"feels" + 0.050*"prove" + 0.050*"declines" + 0.050*"finally" + 0.050*"marry" + 0.050*"forrest" + 0.050*"jenny"'),
#  (6,
#   '0.047*"forrest" + 0.024*"shrimp" + 0.024*"boat" + 0.012*"success" + 0.012*"entire" + 0.012*"country" + 0.012*"letter" + 0.012*"stop" + 0.012*"times" + 0.012*"television"'),
#  (7,
#   '0.054*"pingpong" + 0.054*"forrest" + 0.028*"competitively" + 0.028*"bullet" + 0.028*"butttox" + 0.028*"status" + 0.028*"celebrity" + 0.028*"chinese" + 0.028*"gaining" + 0.028*"teams"'),
#  (8,
#   '0.005*"pingpong" + 0.005*"patrol" + 0.005*"popularity" + 0.005*"playing" + 0.005*"platoon" + 0.005*"probably" + 0.005*"picks" + 0.005*"paddles" + 0.005*"pages" + 0.005*"proposes"'),
#  (9,
#   '0.005*"pingpong" + 0.005*"patrol" + 0.005*"popularity" + 0.005*"playing" + 0.005*"platoon" + 0.005*"probably" + 0.005*"picks" + 0.005*"paddles" + 0.005*"pages" + 0.005*"proposes"'),
#  (10,
#   '0.070*"washington" + 0.070*"rally" + 0.070*"antiwar" + 0.070*"dc" + 0.003*"popularity" + 0.003*"playing" + 0.003*"platoon" + 0.003*"pingpong" + 0.003*"probably" + 0.003*"pages"'),
#  (11,
#   '0.076*"forrest" + 0.039*"film" + 0.039*"bus" + 0.039*"stop" + 0.039*"gump" + 0.039*"sitting" + 0.039*"georgia" + 0.039*"savannah" + 0.039*"falling" + 0.039*"begins"'),
#  (12,
#   '0.081*"alabama" + 0.081*"greenbow" + 0.007*"lt" + 0.004*"platoon" + 0.004*"picks" + 0.004*"popularity" + 0.004*"playing" + 0.004*"probably" + 0.004*"pages" + 0.004*"patrol"'),
#  (13,
#   '0.076*"morning" + 0.076*"early" + 0.076*"leaves" + 0.004*"picks" + 0.004*"popularity" + 0.004*"playing" + 0.004*"platoon" + 0.004*"probably" + 0.004*"pingpong" + 0.004*"parallel"'),
#  (14,
#   '0.076*"returns" + 0.039*"visit" + 0.039*"marriage" + 0.039*"mothers" + 0.039*"proposes" + 0.039*"day" + 0.039*"home" + 0.039*"days" + 0.039*"forrest" + 0.039*"jenny"'),
#  (15,
#   '0.053*"skyward" + 0.053*"feather" + 0.053*"caught" + 0.053*"bus" + 0.053*"breeze" + 0.053*"drifts" + 0.053*"away" + 0.053*"pulls" + 0.053*"white" + 0.003*"playing"'),
#  (16,
#   '0.030*"opening" + 0.030*"school" + 0.030*"taking" + 0.030*"seen" + 0.030*"book" + 0.030*"beginning" + 0.030*"feather" + 0.030*"pages" + 0.030*"bubba" + 0.030*"vietnam"'),
#  (17,
#   '0.099*"forrest" + 0.060*"jenny" + 0.021*"pingpong" + 0.021*"earning" + 0.021*"buy" + 0.021*"paddles" + 0.021*"company" + 0.021*"shrimping" + 0.021*"boat" + 0.021*"home"'),
#  (18,
#   '0.005*"pingpong" + 0.005*"patrol" + 0.005*"popularity" + 0.005*"playing" + 0.005*"platoon" + 0.005*"probably" + 0.005*"picks" + 0.005*"paddles" + 0.005*"pages" + 0.005*"proposes"'),
#  (19,
#   '0.107*"lt" + 0.056*"fiancee" + 0.056*"prosthetic" + 0.056*"legs" + 0.056*"dan" + 0.056*"wedding" + 0.056*"attended" + 0.003*"probably" + 0.003*"presentday" + 0.003*"promise"')]

# %%
print('\nPerplexity: ', lda.log_perplexity(corpus))
# Out:
# Perplexity:  -7.961590387839208

# %%
temp3=lda.print_topics()[1][1]
temp4=lda2.print_topics()[1][1]
# print(temp3)
# print(temp4)

# %%
# topics_terms = lda.state.get_lambda()
# topics_terms
# topics_terms.shape
# topics_terms_proba = np.apply_along_axis(lambda x: x/x.sum(),1,topics_terms)
# topics_terms_proba

# %%
word_weight={}
for i in range(total_topics):
    word_topic=lda.print_topics()[i][1].split('+')
    j=0
    for word_probab in word_topic:
        val,wor=word_probab.split('*')
        wor=str(wor)
#         print(wor)
        y=len(wor)
        if j==len(word_topic)-1:
            wor = wor[1:y-1]
        else:
            wor = wor[1:y-2]
#         print(wor)
        if wor in word_weight:
            if word_weight[wor]<val:
                word_weight[wor]=val
        else :
             word_weight[wor]=val
        
        j=j+1

# print(word_weight)
# print(word_weight['start'])

# %%
word_weight_synopsis={}
for i in range(total_topics):
    word_topic2=lda2.print_topics()[i][1].split('+')
    j=0
    for word_probab in word_topic2:
        val,wor=word_probab.split('*')        
        wor=str(wor)
        #print(wor)
        y=len(wor)
        if j==len(word_topic2)-1:
            wor = wor[1:y-1]
        else:
            wor = wor[1:y-2]
        #print(wor)
        if wor in word_weight_synopsis:
            if word_weight_synopsis[wor]<val:
                word_weight_synopsis[wor]=val
        else :
             word_weight_synopsis[wor]=val
        
        j=j+1
        
#print(word_weight_synopsis)

# %%
df3=pd.read_csv('dataset4.csv')
total_size=df3.shape[0]
#total_size

# %%
word_weight_synopsis
# Out:
# {'ability': '0.046',
#  'afterward': ' 0.041',
#  'alabama': '0.081',
#  'antiwar': ' 0.070',
#  'apple': ' 0.050',
#  'attended': ' 0.056',
#  'away': ' 0.053',
#  'beginning': ' 0.030',
#  'begins': ' 0.039',
#  'boat': ' 0.024',
#  'book': ' 0.030',
#  'braces': ' 0.046',
#  'breeze': ' 0.053',
#  'bubba': ' 0.030',
#  'bullet': ' 0.028',
#  'bus': ' 0.053',
#  'butttox': ' 0.028',
#  'buy': ' 0.021',
#  'caught': ' 0.053',
#  'celebrity': ' 0.028',
#  'chinese': ' 0.028',
#  'college': ' 0.046',
#  'company': ' 0.021',
#  'competitively': ' 0.028',
#  'computer': ' 0.050',
#  'country': ' 0.012',
#  'dan': ' 0.056',
#  'day': ' 0.039',
#  'days': ' 0.039',
#  'dc': ' 0.070',
#  'declines': ' 0.050',
#  'dies': ' 0.041',
#  'different': ' 0.029',
#  'discarded': ' 0.046',
#  'drifts': ' 0.053',
#  'early': ' 0.076',
#  'earning': ' 0.021',
#  'ends': ' 0.041',
#  'entire': ' 0.012',
#  'falling': ' 0.039',
#  'father': ' 0.041',
#  'feather': ' 0.053',
#  'feels': ' 0.050',
#  'fiancee': ' 0.056',
#  'film': ' 0.039',
#  'finally': ' 0.050',
#  'financially': ' 0.050',
#  'football': ' 0.046',
#  'forrest': '0.099',
#  'forrests': ' 0.041',
#  'gaining': ' 0.028',
#  'georgia': ' 0.039',
#  'gets': ' 0.046',
#  'greenbow': ' 0.081',
#  'gump': ' 0.039',
#  'having': ' 0.046',
#  'home': ' 0.039',
#  'invests': '0.050',
#  'jenny': ' 0.060',
#  'leaves': ' 0.076',
#  'legs': ' 0.056',
#  'letter': ' 0.012',
#  'life': '0.029',
#  'lightning': ' 0.046',
#  'love': '0.050',
#  'lt': '0.107',
#  'marriage': ' 0.039',
#  'marry': ' 0.050',
#  'meets': ' 0.029',
#  'money': ' 0.050',
#  'morning': '0.076',
#  'mothers': ' 0.039',
#  'narration': ' 0.029',
#  'obliged': ' 0.050',
#  'opening': '0.030',
#  'paddles': ' 0.021',
#  'pages': ' 0.030',
#  'parallel': ' 0.004',
#  'patrol': ' 0.005',
#  'picks': ' 0.005',
#  'pingpong': '0.054',
#  'platoon': ' 0.005',
#  'playing': ' 0.005',
#  'popularity': ' 0.005',
#  'presentday': ' 0.003',
#  'probably': ' 0.005',
#  'promise': ' 0.003',
#  'proposes': ' 0.039',
#  'prosthetic': ' 0.056',
#  'prove': ' 0.050',
#  'pulls': ' 0.053',
#  'rally': ' 0.070',
#  'regularly': ' 0.029',
#  'rest': ' 0.050',
#  'returns': '0.076',
#  'run': ' 0.046',
#  'savannah': ' 0.039',
#  'scholarship': ' 0.046',
#  'school': '0.079',
#  'secure': ' 0.050',
#  'seen': ' 0.030',
#  'shrimp': ' 0.024',
#  'shrimping': ' 0.021',
#  'sitting': ' 0.039',
#  'skyward': '0.053',
#  'sleeping': ' 0.050',
#  'son': ' 0.041',
#  'status': ' 0.028',
#  'stop': ' 0.039',
#  'success': ' 0.012',
#  'taking': ' 0.030',
#  'teams': ' 0.028',
#  'television': ' 0.012',
#  'times': ' 0.029',
#  'veneration': ' 0.029',
#  'vietnam': ' 0.030',
#  'visit': ' 0.039',
#  'waiting': ' 0.041',
#  'washington': '0.070',
#  'wedding': ' 0.056',
#  'white': ' 0.053'}

# %%
output_list=[]
threshold2=0.01
counter=0
for j in range(total_size):
    comment_t=df3['Comment'][j]
    if df3['Y'][j] == 0:
        counter+=1

    comment_t=clean_text_round1(comment_t)
    s1=comment_t.split(" ")
    comment_ts=set(s1)
    comment_ts
    sum=0
    sum2=0
    sum3=0
    for i in word_weight_synopsis.values():
        sum3+=float(i)*float(i)  
        
    for i in comment_ts:
        if i in word_weight :
            sum2+=float(word_weight[i])*float(word_weight[i])
        if i in word_weight_synopsis and i in word_weight and float(word_weight_synopsis[i])>threshold2:
            sum+=float(word_weight_synopsis[i])*float(word_weight[i])                     
    if sum2!=0 :
        output_list.append(sum/(np.sqrt(sum2)*np.sqrt(sum3)))
    else:
        output_list.append(0)
#print(counter)  
#output_list

# %%
df3['output']=output_list
df3.to_csv('final.csv')

# %%
total=0
false_positive=0
false_negative=0
true_positive=0
true_negative=0
threshold=0.11


for i in range(total_size):
    #print(df3['output'][i],threshold,df3['Y'][i])
    if df3['output'][i]>threshold and df3['Y'][i]==True  :
        true_positive+=1
    if  df3['output'][i]<threshold and df3['Y'][i]==False :
        true_negative+=1
    if df3['output'][i]>threshold and df3['Y'][i]==False:
        false_positive+=1
    if df3['output'][i]<threshold and df3['Y'][i]==True:
        false_negative+=1
        
print(true_positive,true_negative)
print(false_negative,false_positive)
print((true_negative+true_positive)/total_size)

precision=true_positive/(true_positive+false_positive)
recall=true_positive/(true_positive+false_negative)
f1score=(2*precision*recall)/(precision+recall)
print(f1score)
# Out:
# 150 202
# 48 296
# 0.5057471264367817
# 0.46583850931677023
